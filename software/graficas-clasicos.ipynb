# %% [markdown]
# # Gráficas de los polinomios ortogonales clásicos
# **Juan Antonio Villegas Recio**
# > Nota: Este Notebook debe ser ejecutado utilizando un 'kernel' de SageMath, preferiblemente con una versión igual o superior a la 9.3.

# %% [markdown]
# En este notebook mostraremos los códigos con los cuales hemos creado las imágenes de las gráficas del capítulo 2.
# Además, proporcionamos gráficas interactivas para poder observar de manera gráfica el impacto que provocan los distintos parámetros en los polinomios.
#
# En primer lugar, presentamos los códigos con los que se han creado las imágenes de la introducción. Para mejor documentación del código sugerimos consultar el archivo `ceros.ipynb`.

# %% [markdown]
# ## Polinomios de Hermite

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['red', 'green', 'blue', 'black', 'brown', 'orange'] # Colores de las curvas
for j, color in zip(range(6), colors):
    pol = hermite(j,x)
    P += plot(pol, -2, 2, color=color)
P.show()
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# ## Polinomios de Laguerre

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['red', 'green', 'blue', 'black', 'brown', 'orange'] # Colores de las curvas
for j, color in zip(range(6), colors):
    pol = laguerre(j,x)
    P += plot(pol, 0, 6, color=color)
P.show()
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# ## Polinomios de Jacobi

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['red', 'green', 'blue', 'black', 'brown', 'orange'] # Colores de las curvas
for j, color in zip(range(6), colors):
    pol = jacobi_P(j,0,0,x)
    P += plot(pol, -1, 1, color=color)
P.show()
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# # Gráficas interactivas

# %% [markdown]
# Para hacer gráficas interactivas necesitamos la biblioteca `interact`. Además, debido a algunos conflictos con la funcionalidad nativa, hemos creado funciones que calculan los polinomios de Hermite, Laguerre y Jacobi utilizando la fórmula de Rodrigues.

# %%
from sage.repl.ipython_kernel.interact import interact

def Rodrigues_H(n):
    ''' Calcula el polinomio de Hermite de grado n utilizando
        la formula de Rodrigues
    '''
    Bn = (-1)**n
    rho_inv = e**(x**2)
    der = derivative(e**(-x**2),x,n)
    return (Bn*rho_inv*der).full_simplify()

def Rodrigues_L(n, alpha):
    ''' Calcula el polinomio de Laguerre de grado n y parametro 
        'alpha' utilizando la formula de Rodrigues
    '''
    Bn = 1/factorial(n)
    rho_inv = pow(x,-alpha)*e**x
    der = derivative(x**(n+alpha)*e**(-x),x,n)
    return (Bn*rho_inv*der).full_simplify()

def Rodrigues_J(n, alpha, beta):
    ''' Calcula el polinomio de Jacobi de grado n y parametros 
        'alpha' y 'beta' utilizando la formula de Rodrigues
    '''
    Bn = (-1)**n/(2**n*factorial(n))
    rho_inv = pow(1-x, -alpha)*pow(1+x, -beta)
    der = derivative(pow(1-x, n+alpha)*pow(1+x, n+beta),x,n)
    return Bn*rho_inv*der

# %% [markdown]
# Con los siguientes comandos creamos las gráficas interactivas

# %% [markdown]
# ## Hermite

# %%
@interact
def Hermite_plot(n=(0,10), a=(-10,0,0.1), b=(0,10,0.1)):
    pol = Rodrigues_H(n)
    plot(pol, a, b, color='red').show()
# Out:
# Interactive function <function Hermite_plot at 0x7fe52ddcab80> with 3 widgets
#   n: IntSlider(value=5, descript…

# %% [markdown]
# ## Laguerre

# %%
@interact
def Laguerre_plot(n=(0,10), alpha=(0,10,0.1), a=(0,20,0.1), b=(1,50,0.1)):
    pol = Rodrigues_L(n, alpha)
    plot(pol, x, a, b, color='red').show()
# Out:
# Interactive function <function Laguerre_plot at 0x7fe51a38d280> with 4 widgets
#   n: IntSlider(value=5, descrip…

# %% [markdown]
# ## Jacobi

# %%
@interact
def plot_Jacobi(n=(0,10), alpha=(0,10,0.1), beta=(0,10,0.1), a=(-1,0,0.1), b=(0,1,0.1)):
    pol = Rodrigues_J(n, alpha, beta)
    plot(pol, x, a, b, color='red').show()
# Out:
# Interactive function <function plot_Jacobi at 0x7fe51a375790> with 5 widgets
#   n: IntSlider(value=5, descripti…

# %% [markdown]
# # Gráficas para la memoria

# %% [markdown]
# A continuación presentaremos los comandos utilizados para generar las gráficas que aparecen en la sección 2.4 de la memoria.

# %%
legend_size = 16 # Tamaño de la leyenda

# %% [markdown]
# ## Hermite

# %% [markdown]
# Construiremos gráficas con los polinomios de Hermite de diferentes grados.
#
# En primer lugar, veámos los polinomios de Hermite de grado 0, 1 y 2:

# %%
P = plot([]) # Gráfica inicialmente vacía
#colors = ['red', 'green', 'blue', 'black', 'brown', 'orange'] # Colores de las curvas
colors = ['red', 'green', 'blue']
for j, color in zip(range(len(colors)), colors):
    pol = hermite(j,x)
    P += plot(pol, -1, 1, color=color, legend_label='$H_{' + str(j) + '}(x)$')
P.set_legend_options(font_size=legend_size, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Hermite1.png")
P.show()
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# Polinomios de Hermite de grado 3, 4 y 5:

# %%
P = plot([]) # Gráfica inicialmente vacía
#colors = ['red', 'green', 'blue', 'black', 'brown', 'orange'] # Colores de las curvas
colors = ['black', 'brown', 'orange']
for j, color in zip(range(3,3+len(colors)), colors):
    pol = hermite(j,x)
    P += plot(pol, -2.1, 2.1, color=color,legend_label='$H_{' + str(j) + '}(x)$')
P.set_legend_options(font_size=legend_size, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Hermite2.png")
P.show()
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# Polinomios de Hermite de grado 6, 7 y 8:

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['#00235B', '#E21818', '#FFDD83']
for j, color in zip(range(6,6+len(colors)), colors):
    pol = hermite(j,x)
    P += plot(pol, -3, 3, color=color,legend_label='$H_{' + str(j) + '}(x)$')
P.set_legend_options(font_size=legend_size, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Hermite3.png")
P.show()
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# # Laguerre

# %% [markdown]
# Continuamos con los polinomios de Laguerre. Esta familia de polinomios cuenta con un parámetro $\alpha > -1$. Para poder observar el impacto de este parámetro en las gráficas, fijaremos un grado determinado y representaremos gráficas para distintos valores de $\alpha$.
#
# En la siguiente gráfica vemos los polinomios de Laguerre de grado $2$ con distintos valores no negativos de $\alpha$.

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['red', 'green', 'blue', 'black', 'brown', 'orange'] # Colores de las curvas
varsalpha = [0, 1, 5, 15, 20, 25]
for j, alpha, color in zip(range(6), varsalpha , colors):
    pol = Rodrigues_L(2,alpha)
    P += plot(pol, 0, 60, color=color, legend_label='$L_{' + str(2) + '}^{(' + '%.1f' % alpha + ')}(x)$')
P.set_legend_options(font_size=legend_size, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Laguerre1.png")
P.show()
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# Si cambiamos a grado $3$, vemos que cambia el límite cuando $x\rightarrow\infty$, pero para valores pequeños de $\alpha$ el crecimiento es mayor.

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['red', 'green', 'blue', 'black', 'brown', 'orange'] # Colores de las curvas
varsalpha = [0, 1, 5, 15, 20, 25]
for j, alpha, color in zip(range(6), varsalpha , colors):
    pol = Rodrigues_L(3,alpha)
    P += plot(pol, 0, 60, color=color, legend_label='$L_{' + str(3) + '}^{(' + '%.1f' % alpha + ')}(x)$')
P.set_legend_options(font_size=legend_size, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Laguerre2.png")
P.show()
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# Utilizamos ahora valores negativos para $\alpha$.

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['red', 'green', 'blue', 'black', 'brown', 'orange'] # Colores de las curvas
varsalpha = [-0.9, -0.5, 0, 0.5, 1]
for j, alpha, color in zip(range(6), varsalpha , colors):
    pol = Rodrigues_L(3,alpha)
    P += plot(pol, 0, 8, color=color, legend_label='$L_{' + str(3) + '}^{(' + '%.1f' % alpha + ')}(x)$')
P.set_legend_options(font_size=legend_size, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Laguerre3.png")
P.show()
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# Fijado $\alpha=0$, mostraremos las gráficas de $L_n^{(0)}$ para distintos valores de $n$. En primer lugar, para $n=0,1,2$:

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['red', 'green', 'blue', 'black', 'brown', 'orange'] # Colores de las curvas
varsalpha = [-0.9, -0.5, 0, 0.5, 1]
for j, color in zip(range(3) , colors):
    pol = Rodrigues_L(j,0)
    P += plot(pol, 0, 4.1, color=color, legend_label='$L_{' + str(j) + '}^{(' + str(0) + ')}(x)$')
P.set_legend_options(font_size=legend_size, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Laguerre4.png")
P.show()
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# Seguidamente, mostraremos los grados 3, 4 y 5 con dos rangos de valores distintos, ya que los ceros de los polinomios de grados pequeños están situados en subintervalos más pequeños de $[0,+\infty)$.

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['black', 'brown', 'orange'] # Colores de las curvas
varsalpha = [-0.9, -0.5, 0, 0.5, 1]
for j, color in zip(range(3,6) , colors):
    pol = Rodrigues_L(j,0)
    P += plot(pol, 0, 8, color=color, legend_label='$L_{' + str(j) + '}^{(' + str(0) + ')}(x)$')
P.set_legend_options(font_size=legend_size, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Laguerre5.png")
P.show()
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['black', 'brown', 'orange'] # Colores de las curvas
varsalpha = [-0.9, -0.5, 0, 0.5, 1]
for j, color in zip(range(3,6) , colors):
    pol = Rodrigues_L(j,0)
    P += plot(pol, 0, 15, color=color, legend_label='$L_{' + str(j) + '}^{(' + str(0) + ')}(x)$')
P.set_legend_options(font_size=legend_size, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Laguerre6.png")
P.show()
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# Continuamos mostrando los grados 6, 7 y 8, también utilizando rangos de valores distintos.

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['#00235B', '#E21818', '#FFDD83']
varsalpha = [-0.9, -0.5, 0, 0.5, 1]
for j, color in zip(range(6,9) , colors):
    pol = Rodrigues_L(j,0)
    P += plot(pol, 1, 10, color=color, legend_label='$L_{' + str(j) + '}^{(' + str(0) + ')}(x)$')
P.set_legend_options(font_size=14, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Laguerre7.png")
P.show()
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['#00235B', '#E21818', '#FFDD83']
varsalpha = [-0.9, -0.5, 0, 0.5, 1]
for j, color in zip(range(6,9) , colors):
    pol = Rodrigues_L(j,0)
    P += plot(pol, 1, 25, color=color, legend_label='$L_{' + str(j) + '}^{(' + str(0) + ')}(x)$')
P.set_legend_options(font_size=legend_size, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Laguerre8.png")
P.show()
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# ## Jacobi

# %% [markdown]
# Por último, presentaremos algunas imágenes de los polinomios de Jacobi. Esta familia de polinomios cuenta con dos parámetros $\alpha,\beta > -1$. Para ver el impacto de cada uno de ellos, fijaremos uno y moveremos el otro, fijando el grado.
#
# En la siguiente gráfica vemos los polinomios de Jacobi de grado $2$ con distintos valores no negativos de $\alpha$ y $\beta=0$.

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['red', 'green', 'blue', 'black', 'brown', 'orange'] # Colores de las curvas
varsalpha = [0, 1, 5, 15, 20, 25]
for j, alpha, color in zip(range(6), varsalpha , colors):
    pol = Rodrigues_J(2,alpha,0.0)
    P += plot(pol, -1, 1, color=color, legend_label='$P_{' + str(2) + '}^{(' + '%.1f' % alpha + ', 0.0)}(x)$')
P.set_legend_options(font_size=14, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Jacobi1.png")
P.show()
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# En la siguiente fijamos $n=3$, $\alpha=0$ y observamos gráficas con valores no negativos de $\alpha$.

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['red', 'green', 'blue', 'black', 'brown', 'orange'] # Colores de las curvas
varsalpha = [0, 1, 5, 15, 20, 25]
for j, alpha, color in zip(range(6), varsalpha , colors):
    pol = Rodrigues_J(3,0.0,alpha)
    P += plot(pol, -1, 1, color=color, legend_label='$P_{' + str(3) + '}^{(0.0, ' + '%.1f' % alpha + ')}(x)$')
P.set_legend_options(font_size=14, bbox_to_anchor=(1, 0.9, 0, 0))
P.save("../memoria/img/C2/Jacobi2.png")
P.show()
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# Fijado $n=3$, veámos gráficas en las que $\alpha=\beta$ probando distintos valores $-1 < \alpha,\beta \leq 1$.

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['red', 'green', 'blue', 'black', 'brown', 'orange'] # Colores de las curvas
varsalpha = [-0.9, -0.5, 0, 0.5, 1]
for j, alpha, color in zip(range(6), varsalpha , colors):
    pol = Rodrigues_J(3,alpha,alpha)
    P += plot(pol, -1, 1, color=color, legend_label='$P_{' + str(3) + '}^{(' + '%.1f' % alpha + ', ' + '%.1f' % alpha + ')}(x)$')
P.set_legend_options(font_size=14, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Jacobi3.png")
P.show()
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# Fijemos ahora $n=4$.

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['red', 'green', 'blue', 'black', 'brown', 'orange'] # Colores de las curvas
varsalpha = [-0.9, -0.5, 0, 0.5, 1]
for j, alpha, color in zip(range(6), varsalpha , colors):
    pol = Rodrigues_J(4,alpha,alpha)
    P += plot(pol, -1, 1, color=color, legend_label='$P_{' + str(4) + '}^{(' + '%.1f' % alpha + ', ' + '%.1f' % alpha + ')}(x)$')
P.set_legend_options(font_size=14, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Jacobi4.png")
P.show()
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# En estas últimas gráficas fijamos $\alpha=\beta=0$ y observamos gráficas para distintos valores del grado $n$ del polinomio.
#
# En primer lugar, véanse las gráficas para los grados 0, 1 y 2:

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['red', 'green', 'blue'] # Colores de las curvas
for j, color in zip(range(3) , colors):
    pol = Rodrigues_J(j,0,0)
    P += plot(pol, -1, 1, color=color, legend_label='$P_{' + str(j) + '}^{(0,0)}(x)$')
P.set_legend_options(font_size=14, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Jacobi5.png")
P.show()
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# Grados 3, 4 y 5:

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['black', 'brown', 'orange'] # Colores de las curvas
for j, color in zip(range(3,6) , colors):
    pol = Rodrigues_J(j,0,0)
    P += plot(pol, -1, 1, color=color, legend_label='$P_{' + str(j) + '}^{(0,0)}(x)$')
P.set_legend_options(font_size=14, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Jacobi6.png")
P.show()
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# Grados 6, 7 y 8:

# %%
P = plot([]) # Gráfica inicialmente vacía
colors = ['#00235B', '#E21818', '#FFDD83']# Colores de las curvas
for j, color in zip(range(6,9) , colors):
    pol = Rodrigues_J(j,0,0)
    P += plot(pol, -1, 1, color=color, legend_label='$P_{' + str(j) + '}^{(0,0)}(x)$')
P.set_legend_options(font_size=14, bbox_to_anchor=(1, 1, 0, 0))
P.save("../memoria/img/C2/Jacobi7.png")
P.show()
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# En este documento se ofrecen muchas imágenes de distintas gráficas junto con el código utilizado para generarlas, que esperamos pueda servir de ayuda a quien lo pueda necesitar.
